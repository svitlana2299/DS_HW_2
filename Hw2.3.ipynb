# %% [markdown]
# Прочитайте csv файл (використовуйте функцію read_csv)

# %%
import pandas as pd
import matplotlib.pyplot as plt

file_id = '1ERmZE5goTbYXpj5QJUj9omClqW2St3Ml'

url = f'https://drive.google.com/uc?id={file_id}'
df = pd.read_csv(url)
df
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %% [markdown]
# Виведіть перші п'ять рядків (використовується функція head)

# %%
print("Перші п'ять рядків:")
df.head()
# Out:
# Перші п'ять рядків:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %% [markdown]
# Виведіть розміри датасету (використовуйте атрибут shape)

# %%
print("\nРозміри датасету:")
df.shape

# %% [markdown]
# Відповідь: Про скільки книг зберігає дані датасет?

# %%
print("\nВідповідь: Датасет містить інформацію про", df.shape[0], "книг.")
df.columns = ['name', 'author', 'user_rating', 'reviews', 'price', 'year', 'genre']
print("\nНові назви стовпців:")
df.head()
# Out:
# Відповідь: Датасет містить інформацію про 550 книг.
#
# Нові назви стовпців:
#                                                 name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      author  user_rating  reviews  price  year        genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %% [markdown]
# Перевірити пропуски

# %%
print("\nКількість пропусків у кожному стовпці:")
df.isna().sum()

# %%
print("\nВідповідь: Пропуски є у стовпці 'author'.")

# %% [markdown]
# Унікальні значення у стовпці 'genre'

# %%
print("\nУнікальні жанри:")
df['genre'].unique()
# Out:
# Унікальні жанри:
# array(['Non Fiction', 'Fiction'], dtype=object)

# %% [markdown]
# Побудувати гістограму цін

# %%
df['price'].plot(kind='hist', bins=20, title='Розподіл цін')
plt.xlabel('Ціна')
plt.ylabel('Кількість книг')
plt.show()

# %%
print("\nВідповіді:")
print("Максимальна ціна:", df['price'].max())
print("Мінімальна ціна:", df['price'].min())
print("Середня ціна:", df['price'].mean())
print("Медіанна ціна:", df['price'].median())
# Out:
# Відповіді:
# Максимальна ціна: 105
# Мінімальна ціна: 0
# Середня ціна: 13.1
# Медіанна ціна: 11.0

# %%
max_rating = df['user_rating'].max()
print("Відповідь: Найвищий рейтинг у датасеті:")
max_rating
# Out:
# Відповідь: Найвищий рейтинг у датасеті:
# 4.9

# %%
num_books_max_rating = df[df['user_rating'] == max_rating].shape[0]
print("Відповідь: Кількість книг із найвищим рейтингом:")
num_books_max_rating
# Out:
# Відповідь: Кількість книг із найвищим рейтингом:
# 52

# %%
max_reviews_book = df[df['reviews'] == df['reviews'].max()]['name'].values[0]
print("Відповідь: Книга з найбільшою кількістю відгуків:")
max_reviews_book
# Out:
# Відповідь: Книга з найбільшою кількістю відгуків:
# 'Where the Crawdads Sing'

# %%
df_2015 = df[df['year'] == 2015]
df_2015
# Out:
#                                                   name  \
# 16   Adult Coloring Book: Stress Relieving Animal D...
# 17      Adult Coloring Book: Stress Relieving Patterns
# 18   Adult Coloring Books: A Coloring Book for Adul...
# 21                         All the Light We Cannot See
# 23   American Sniper: The Autobiography of the Most...
# 28                        Baby Touch and Feel: Animals
# 29            Balance (Angie's Extreme Stress Menders)
# 34   Being Mortal: Medicine and What Matters in the...
# 35                            Between the World and Me
# 54   Creative Haven Creative Cats Coloring Book (Ad...
# 55   Creative Haven Owls Coloring Book (Adult Color...
# 63                      Dear Zoo: A Lift-the-Flap Book
# 89   Dover Creative Haven Art Nouveau Animal Design...
# 99   Enchanted Forest: An Inky Quest and Coloring b...
# 111                                    First 100 Words
# 123                               Giraffes Can't Dance
# ...

# %%
most_expensive_2015 = df_2015[df_2015['price'] == df_2015['price'].max()]['name'].values[0]
print("Відповідь: Найдорожча книга у 2015 році:")
most_expensive_2015
# Out:
# Відповідь: Найдорожча книга у 2015 році:
# 'Publication Manual of the American Psychological Association, 6th Edition'

# %%
num_fiction_2010 = df[(df['genre'] == 'Fiction') & (df['year'] == 2010)].shape[0]
print("Відповідь: Кількість книг жанру Fiction у Топ-50 у 2010 році:")
num_fiction_2010
# Out:
# Відповідь: Кількість книг жанру Fiction у Топ-50 у 2010 році:
# 20

# %%
num_high_rating_2010_2011 = df[(df['user_rating'] == 4.9) & ((df['year'] == 2010) | (df['year'] == 2011))].shape[0]
print("Відповідь: Кількість книг із рейтингом 4.9 у 2010 та 2011 роках:")
num_high_rating_2010_2011
# Out:
# Відповідь: Кількість книг із рейтингом 4.9 у 2010 та 2011 роках:
# 1

# %%
sorted_books_2015 = df[(df['year'] == 2015) & (df['price'] < 8)].sort_values(by='price')
sorted_books_2015
# Out:
#                                                   name              author  \
# 507                              To Kill a Mockingbird          Harper Lee
# 210                      Laugh-Out-Loud Jokes for Kids         Rob Elliott
# 206                         Knock-Knock Jokes for Kids         Rob Elliott
# 111                                    First 100 Words        Roger Priddy
# 123                               Giraffes Can't Dance       Giles Andreae
# 54   Creative Haven Creative Cats Coloring Book (Ad...     Marjorie Sarnat
# 63                      Dear Zoo: A Lift-the-Flap Book        Rod Campbell
# 89   Dover Creative Haven Art Nouveau Animal Design...         Marty Noble
# 478                        The Very Hungry Caterpillar          Eric Carle
# 201  Killing Reagan: The Violent Assault That Chang...       Bill O'Reilly
# 28                        Baby Touch and Feel: Animals                  DK
# ...

# %%
print("\nВідповідь:")
print("Книга остання у відсортованому списку:", sorted_books_2015['name'].iloc[-1])
# Out:
# Відповідь:
# Книга остання у відсортованому списку: Old School (Diary of a Wimpy Kid #10)

# %%
genre_prices = df.groupby('genre')['price'].agg(['max', 'min'])
print("\nВідповідь:")
print("Максимальна ціна для жанру Fiction:", genre_prices.loc['Fiction', 'max'])
print("Мінімальна ціна для жанру Fiction:", genre_prices.loc['Fiction', 'min'])
print("Максимальна ціна для жанру Non Fiction:", genre_prices.loc['Non Fiction', 'max'])
print("Мінімальна ціна для жанру Non Fiction:", genre_prices.loc['Non Fiction', 'min'])
# Out:
# Відповідь:
# Максимальна ціна для жанру Fiction: 82
# Мінімальна ціна для жанру Fiction: 0
# Максимальна ціна для жанру Non Fiction: 105
# Мінімальна ціна для жанру Non Fiction: 0

# %%
author_book_count = df.groupby('author')['name'].count()
print("\nВідповідь:")
print("Розмірність таблиці (кількість рядків):", author_book_count.shape[0])
print("Автор із найбільшою кількістю книг:", author_book_count.idxmax())
print("Кількість книг цього автора:", author_book_count.max())
# Out:
# Відповідь:
# Розмірність таблиці (кількість рядків): 248
# Автор із найбільшою кількістю книг: Jeff Kinney
# Кількість книг цього автора: 12

# %%
author_avg_rating = df.groupby('author')['user_rating'].mean()
print("\nВідповідь:")
print("Автор із мінімальним середнім рейтингом:", author_avg_rating.idxmin())
print("Середній рейтинг цього автора:", author_avg_rating.min())
# Out:
# Відповідь:
# Автор із мінімальним середнім рейтингом: Donna Tartt
# Середній рейтинг цього автора: 3.9

# %%
author_stats = pd.concat([author_book_count, author_avg_rating], axis=1, keys=['book_count', 'avg_rating'])
author_stats
# Out:
#                             book_count  avg_rating
# author
# Abraham Verghese                     2    4.600000
# Adam Gasiewski                       1    4.400000
# Adam Mansbach                        1    4.800000
# Adir Levy                            1    4.800000
# Admiral William H. McRaven           1    4.700000
# ...                                ...         ...
# Walter Isaacson                      3    4.566667
# William Davis                        2    4.400000
# William P. Young                     2    4.600000
# Wizards RPG Team                     3    4.800000
# Zhi Gang Sha                         2    4.600000
#
# [248 rows x 2 columns]

# %%
sorted_author_stats = author_stats.sort_values(by=['book_count', 'avg_rating'])
sorted_author_stats
# Out:
#                                     book_count  avg_rating
# author
# Muriel Barbery                               1    4.000000
# Chris Cleave                                 1    4.100000
# Ian K. Smith M.D.                            1    4.100000
# Pierre Dukan                                 1    4.100000
# Elizabeth Strout                             1    4.200000
# ...                                        ...         ...
# American Psychological Association          10    4.500000
# Suzanne Collins                             11    4.663636
# Gary Chapman                                11    4.736364
# Rick Riordan                                11    4.772727
# Jeff Kinney                                 12    4.800000
#
# [248 rows x 2 columns]

# %%
print("\nВідповідь:")
print("Перший автор у списку:", sorted_author_stats.index[0])
# Out:
# Відповідь:
# Перший автор у списку: Muriel Barbery

# %% [markdown]
# Додайте від 3 до 5 графіків функцій різного типу на ваш вибір. Задайте графікам оформлення, щоб кожен графік у своїй домашній роботі чимось відрізнявся і не був схожим на інші. Можна використовувати як matplotlib, так і seaborn.

# %% [markdown]
# **Графік 1: Розподіл рейтингів**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

plt.figure(figsize=(10, 6))
sns.histplot(df['user_rating'], bins=20, kde=True, color='skyblue')
plt.title('Розподіл рейтингів книг')
plt.xlabel('Рейтинг')
plt.ylabel('Частота')
plt.show()

# %% [markdown]
# **Графік 2: Взаємозв'язок між рейтингом і кількістю відгуків**

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='user_rating', y='reviews', data=df, color='coral')
plt.title('Взаємозв\'язок між рейтингом і кількістю відгуків')
plt.xlabel('Рейтинг')
plt.ylabel('Кількість відгуків')
plt.show()

# %% [markdown]
# **Графік 3: Розподіл цін**

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['price'], bins=20, kde=True, color='lightgreen')
plt.title('Розподіл цін на книги')
plt.xlabel('Ціна')
plt.ylabel('Частота')
plt.show()

# %% [markdown]
# **Графік 4: Кількість книг у кожному жанрі**

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='genre', data=df, palette='viridis')
plt.title('Кількість книг у кожному жанрі')
plt.xlabel('Жанр')
plt.ylabel('Кількість книг')
plt.show()

# %% [markdown]
# **Графік 5: Парна діаграма між ціною та рейтингом**

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='price', y='user_rating', data=df, hue='genre', palette='husl')
plt.title('Парна діаграма між ціною та рейтингом з розподілом за жанром')
plt.xlabel('Ціна')
plt.ylabel('Рейтинг')
plt.show()
